# %%
#W8A1
try:
  a=int(input("Nhập a: "))
  b=int(input("Nhập b: "))
  c=a/b
  print(f"{c:.2f}")
except ZeroDivisionError:
  print("Lỗi không thể chia hết cho 0 ")
# Out:
# Nhập a: 1
# Nhập b: 0
# Lỗi không thể chia hết cho 0

# %%
#W8A2
try:
  my_list=list(map(int,input().split()))
  n=int(input())
  print(my_list[n])
except IndexError:
  print("Lỗi truy cập chỉ số sai!")
# Out:
# 1 2 3
# 4
# Lỗi truy cập chỉ số sai!

# %%
#W8A3
def sum_square_digit(n):
  tong=0
  while n>0:
    so = n % 10
    tong = so * so
    n //= 10
  return tong
def is_happy(a):
  seen = set()
  while a != 1:
    if a in seen :
      return False
    seen.add(a)
    a = sum_square_digit(a)
  return True
try:
  a=int(input())
  if a <= 0:
    print("Nhập sai")
  else:
    if is_happy(a):
      print("Yes")
    else:
      print("No")
except ValueError:
  print("ValueError: Dữ liệu nhập vào không hợp lệ")
# Out:
# 7
# Yes

# %%
#W8A4
try:
  a,b=map(int,input().split())
  tong=a+b
except ValueError:
  print("Lỗi: Bạn phải nhập số nguyên!")
else:
  print("Tổng hai số là:", tong)
finally:
  print("Kết thúc chương trình.")
# Out:
# 3 4
# Tổng hai số là: 7
# Kết thúc chương trình.

# %%
#W8A5
a=input().split(" ")
kq=[]
for x in a:
  try:
    x=int(float(x))
    kq.append(x)
  except:
    print(f'khong chuyen {x} sang int duoc')
print(kq)
# Out:
# a 3 -4 5
# khong chuyen a sang int duoc
# [3, -4, 5]

# %%
#W10A6
import math
n=int(input())
try:
  print(f"{math.sqrt(n):.2f}")
except ValueError:
  print("So am")
# Out:
# -4
# So am

# %%
#W10A7
try:
  n=int(input())
  if n<0:
    print("Tuoi khong hop le")
  else:
    ns=2025-n
    print(ns)
except ValueError:
  print("Tuoi khong hop le")
# Out:
# 8
# 2017

# %%
#W10A8
try:
  file = input().lower()
  if file[-3:] not in ['txt','zip']:
    raise ValueError
except ValueError:
  print("File khong hop le")
else:
  print("Doc file thanh cong")
# Out:
# data.TXT
# Doc file thanh cong

# %%
#W10A9
try:
  m=input()
  n=int(m)
  print(n)
except ValueError:
  print("Chuoi khong hop le")
# Out:
# ABC
# Chuoi khong hop le

# %%
#W10A10
try:
  m=list(map(int,input().split()))
  n=m[0]
  m=m[1:]
  if len(m) != len(set(m)):
    raise ValueError
  print(sum(m))
except ValueError:
  print("Mang khong hop le")
# Out:
# 3 1 1 2
# Mang khong hop le

# %%
#W8A11
import re
try:
  t=int(input())
  for _ in range(t):
    s=input().strip()
    try:
      re.compile(s)
      print("Valid")
    except re.error:
      print("Invalid")
except EOFError:
  pass
# Out:
# 2
# .*\+
# Valid
# .*+
# Valid
